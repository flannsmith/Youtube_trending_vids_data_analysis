# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
sns.set()
from matplotlib import style
from matplotlib.backends.backend_pdf import PdfPages
# %matplotlib inline
# plt.style.use('fivethirtyeight')
#plt.style.use(['ggplot'])
# %config IPCompleter.greedy=True
#plt.style.use(['dark_background'])
plt.style.use('seaborn-dark')
#import json

# %%
FR_csv = pd.read_csv("FRvideos.csv")

# %%
FR_csv
# Out:
#           video_id trending_date  \
# 0      Ro6eob0LrCY      17.14.11
# 1      Yo84eqYwP98      17.14.11
# 2      ceqntSXE-10      17.14.11
# 3      WuTFI5qftCE      17.14.11
# 4      ee6OFs8TdEg      17.14.11
# 5      teXaL6GdQRk      17.14.11
# 6      nduL7G_gJoY      17.14.11
# 7      QmpWE_SODZA      17.14.11
# 8      GBVxEpQr8R8      17.14.11
# 9      0RFhWyM6qbA      17.14.11
# 10     LhjhGOBIoHM      17.14.11
# 11     lnFaRuWOLN0      17.14.11
# 12     LGbUBietbJc      17.14.11
# 13     JfanclGyrZY      17.14.11
# 14     PpECwr15oQQ      17.14.11
# 15     ZTTpRHC5ZH4      17.14.11
# 16     RpEJCznFreQ      17.14.11
# 17     tsMw-VMUtNU      17.14.11
# 18     hdOzPPa_bFY      17.14.11
# 19     7779JdxVAg0      17.14.11
# 20     c0YARs-b5rc      17.14.11
# 21     BdUdHk80Z7U      17.14.11
# 22     1ZAPwfrtAFY      17.14.11
# 23     Wbbj4oZ-Wmo      17.14.11
# 24     PKBfGeMSTb4      17.14.11
# 25     avNyRo2Vd9U      17.14.11
# 26     lQxGAH73DNE      17.14.11
# 27     FGA3qaOl5SM      17.14.11
# 28     exMNBvwCfRY      17.14.11
# 29     8YEGqrtsxBc      17.14.11
# ...            ...           ...
# 28640  9jYlmUW_7K4      18.14.04
# 28641  N4Jwe-ttAq8      18.14.04
# 28642  XRnYB7BeuLc      18.14.04
# 28643  v-LS8wdSAFE      18.14.04
# 28644  5BwUvd22EnU      18.14.04
# 28645  ljBL-97T2rs      18.14.04
# 28646  ZLDYKyTCUE8      18.14.04
# 28647  k48ID5sB3Ig      18.14.04
# 28648  1mqHFQhXKjU      18.14.04
# 28649  g1iBduCk3TU      18.14.04
# 28650  rulSPTGgen8      18.14.04
# 28651  HGPIGS8cFoQ      18.14.04
# 28652  quCwPzAxSJY      18.14.04
# 28653  xgZjulolsXM      18.14.04
# 28654  HrmZKMqoDg8      18.14.04
# 28655  sKA9J0PFbio      18.14.04
# 28656  oBXF0Txdpns      18.14.04
# 28657  3dN1Mremvks      18.14.04
# 28658  EgSF_yDKONc      18.14.04
# 28659  gOQXOdZOXwE      18.14.04
# 28660  QBzQeyHh0i8      18.14.04
# 28661  TPg-N9NPH2Y      18.14.04
# 28662  adWnY1J8BIw      18.14.04
# 28663  0XibZTyuCwo      18.14.04
# 28664  Y-06A9odGXY      18.14.04
# 28665  xXUdsQuUhGY      18.14.04
# 28666  iVFPzrofpkk      18.14.04
# 28667  3z_Cl43lJ7k      18.14.04
# 28668  hRxk8UkoeyI      18.14.04
# 28669  zVd5WMemvpA      18.14.04
#
#                                                    title  \
# 0               Malika LePen : Femme de Gauche - Trailer
# 1      LA PIRE PARTIE ft Le Rire Jaune, Pierre Croce,...
# 2      DESSINS ANIMÉS FRANÇAIS VS RUSSES 2 - Daniil...
# 3                        PAPY GRENIER - METAL GEAR SOLID
# 4      QUI SAUTERA LE PLUS HAUT ? (VÉLO SKATE ROLLER ...
# 5      STRANGER JOKES : Jokes de Papa avec les teens ...
# 6      De retour dans le Manoir hanté avec le Grand J...
# 7      T'es qui toi ? Squeezie, le youtubeur aux 4 mi...
# 8                     ON VOUS DÉVOILE NOTRE VRAI SALAIRE
# 9      Benzema balance ses dur vérités Deschamps et L...
# 10     Jérémy Ferrari - On n'est pas couché 11 novemb...
# 11                          Emilie, 10 ans, Coach De Vie
# 12     J'ABANDONNE UNE PETITE FILLE DEVANT DES INCONN...
# 13                    L'incroyable Joyau de François 1er
# 14                                    Cocovoit - M comme
# 15                 Une nouvelle lune - La Petite Mort #4
# 16                 FAIRE UNE GLACE ROULÉE (sans machine)
# 17     Kid Barely Avoids Getting Run Over by Trailer ...
# 18     JE SUIS PASSÉ À LA TÉLÉ ! (VOS VIDÉOS FOND VER...
# 19     10 FILMS que LES PARENTS CROYAIENT ÊTRE pour E...
# 20         NE DITES PAS ÇA À SIRI (SIRI HANTE MA MAISON)
# 21             J'ai pas lavé ma piscine depuis 30 ans...
# 22     The Trump Presidency: Last Week Tonight with J...
# 23        [Zap Télé] LA FIN DE L'INTELLIGENCE (13/11/17)
# 24     Je change la ligne d'échappement de ma C63s AM...
# 25     10 RECETTES DIY DE BAUME À LÈVRES À PARTIR DE ...
# 26                 Le fascisme, c'est pas bien, par Usul
# 27     NEYMAR craque, BENZEMA et les Bleus, RONALDO e...
# 28                          LES PIRES DOUBLAGES FRANÇAIS
# 29     6 CRITIQUES OCT/NOV (Thor 3 / Carbone / Au Rev...
# ...                                                  ...
# 28640  سـكـتـة قـلـبـيـة 😱 لأم شـهـيـد الـواجـب الـوط...
# 28641  شابة جزائرة حرة تقول كلام مؤثر بعد حــادثة تـح...
# 28642  QUAND LA FRANCE NOUS A FAIT VIBRER !!  [frisso...
# 28643   VOILÀ COMMENT ÊTRE UNE CLÉ DU BIEN. Rachid ELJAY
# 28644                 Un Duo Formidable Maelle et Gulaan
# 28645  Quand tu fais un marathon... (blagues, insolit...
# 28646  Miraculous Ladybug - Ms. Bustier or Marinette ...
# 28647                      Aşk ve Mavi 62.Bölüm Fragmanı
# 28648             رشيد شو: رضى الطلياني ـ الحلقة الكاملة
# 28649  AFTER - OM : PEUVENT-ILS TOUT JOUER À FOND ? (...
# 28650           Polymer Clay Tutorial - Starbucks Coffee
# 28651                                  AVANT VS APRÈS #2
# 28652  لقطة جديدة تبين بوضوح لحظة سقوط الطائرة العسكر...
# 28653  QUE DES LIGNES BRISEES ! - Obstacle à 10h40 - ...
# 28654  PS5, MES INFOS : puissance, fenêtre de lanceme...
# 28655   Washington, Paris et Londres ont frappé la Syrie
# 28656  UNE SAISON AUX ABEILLES - S02E09 - Tancer des ...
# 28657    😉 J’avoue je ne suis pas libre financièrement 😉
# 28658      🔧 Projet C8 🔧on remet le moteur !!  👍 Ep # 11
# 28659  مناوشـــات خطييييرة بين لاعبي الشبيبة و المولو...
# 28660  Victoria Beckham Says Yes to a Spice Girls Car...
# 28661  PARANORMAL URBEX - ÉPISODE 32 : UN RESTAURANT ...
# 28662  ماذا يحدث في ملاعب الجزائر : إشتباكات في المدر...
# 28663  JULIEN (LMA) ALERTE ACCOUCHEMENT pour MANON da...
# 28664  🌸 NIGHTCORE 🌸 AMV / JE ME PERDS ( Jena Lee ) +...
# 28665  【EP.1】跑男团热血回归 竟在维也纳遭遇“史上最难挑战” 鹿晗形象坍塌被吓丢魂 学霸邓超大...
# 28666  MOI VS MA SOEUR!! MINI SLIMES AVEC DES MINI BA...
# 28667  Obsèques de Jacques Hige­lin : sa fille Izia ...
# 28668  LA VRAIE RAISON POURQUOI COD FORLAN A SUPPRIMÉ...
# 28669                              COD forlan le maudit.
#
#                               channel_title  category_id  \
# 0                       Le Raptor Dissident           24
# 1                                   Le Labo           24
# 2                           Daniil le Russe           23
# 3                         Joueur Du Grenier           20
# 4                         Aurelien Fontenoy           17
# 5                     Le Jeu, C'est Sérieux           23
# 6                               silent jill           24
# 7                      Salut les terriens !           24
# 8                           Mcfly & Carlito           24
# 9                                  HALIRIPA           22
# 10                      On n'est pas couché           24
# 11                                 Lolywood           23
# 12                                    RAZMO           24
# 13                                Nota Bene           27
# 14                                 Cocovoit           23
# 15                                 Studio 4           23
# 16                         Alexandre Calvez           26
# 17                                 Pirateay           24
# 18                                 Panormal           20
# 19                               Lama Faché           24
# 20                            Apple Station           28
# 21                               CoD Forlan           24
# 22                          LastWeekTonight           24
# 23                                 Zap Télé           24
# 24                                      GMK            2
# 25                           Troom Troom FR           26
# 26                                Mediapart           25
# 27                              Top Mercato           17
# 28                                 SQUEEZIE           23
# 29                               INTHEPANDA            1
# ...                                     ...          ...
# 28640               شوارع الجزائر Algérie I            1
# 28641                             DZ akhbar           25
# 28642                                PODIUM           17
# 28643  Pr. Rachid Eljay chaine officielle 1           27
# 28644                      jean-marc pierre           22
# 28645                        BEST OF CULTES           23
# 28646                       Miraculoves Bug            1
# 28647                           Aşk ve Mavi            1
# 28648                                  2MTV           24
# 28649                        Zap Actu Sport           17
# 28650                         MissCréatives           24
# 28651             team fan latelierderoxane           26
# 28652                          Messaoud law           25
# 28653                        Horse-Republic           17
# 28654                         Julien Chièze           20
# 28655                             FRANCE 24           25
# 28656                 gOAdee Apiculteur Pro           15
# 28657                          Thami Kabbaj           27
# 28658               La mécanique selon Boul            2
# 28659                              RedsTech           17
# 28660  The Late Late Show with James Corden           22
# 28661                   Le paranormal du 24            1
# 28662                          Best News Dz           22
# 28663                    Gossip Téléréalité           24
# 28664                         ZNightcore 春梦           10
# 28665                 - 欢迎订阅 -浙江卫视【奔跑吧】官方频道           24
# 4      vélo|"vtt"|"bmx"|"freestyle"|"bike"|"mtb"|"dir...   141695    8091
# 5      Stranger Jokes|"Jokes de Papa"|"Stranger Thing...   141253   14354
# 6      fantome|"esprits"|"spiritisme"|"hanté"|"ouija"...   187654    9286
# 7      salut les terriens|"squeezie"|"jeux videos"|"i...    91051    1674
# 8      mcfly|"carlito"|"golden moustache"|"fatshow"|"...  2340941  200598
# 9      Karim benzema football|"Benzema vs cristiano r...   635236    5945
# 10     onpc|"on n'est pas couche"|"laurent ruquier"|"...   294065       0
# 11     Chope squad|"manu"|"Le dernier niveau"|"Le Cou...  1504950  108635
# 12                                                [none]   335121   23410
# 13     Nota Bene|"françois 1er"|"histoire"|"livre d'h...    53248    5164
# 14     cocovoit|"et bim"|"humour"|"covoiturage"|"drôl...    55313    4153
# 15     nouvelles écritures|"studio 4"|"france télévis...   172608    8163
# 16     Alexandre Calvez|"Crash Test"|"Alexandre"|"Cal...   373013   23645
# 17     near accident|"safety"|"danger"|"volvo brakes"...    79611      56
# 18                                                [none]   255349   20069
# 19     dessin animé|"disney"|"top 10"|"top 5"|"top10"...   653398   27773
# 20     apple|"station"|"tech"|"high"|"hitech"|"itech"...   152390    4666
# 21     reaction|"piscine"|"piscine gonflable"|"piscin...   321090   36515
# 22     last week tonight trump presidency|"last week ...  2418783   97192
# 23     robot|"demain tous crétins"|"intelligence arti...    72519     689
# 24     GMK001|"GMK"|"Maroun"|"Kikano"|"C63"|"AMG"|"ca...   166132   13758
# 25     DIY|"baume à lèvres maison"|"EOS"|"gommage"|"g...   240158    6765
# 26     fascisme|"racisme"|"extrême droite"|"manuel va...    49188    4835
# 27     TopMercato|"Foot"|"Football"|"Top Mercato"|"Ka...   160173    6226
# 28     squeezie doublage|"squeezie batman"|"squeezie ...  3641421  218587
# 29     INTHEPANDA|"INTHEPANDA CRITIQUE"|"INTHEPANDA C...   102804    6306
# ...                                                  ...      ...     ...
# 28640                                             [none]   376849    2336
# 28641                                  الأخبار|"الجزائر"   286927    7038
# 28642             football|"france"|"best"|"of"|"moment"     8133     145
# 28643  imam|"Brest"|"Rachid"|"El"|"jay"|"Abou"|"houde...    11701    1240
# 28644                                             [none]    19500     346
# 28645  Quand tu fais un marathon|"marathon"|"blagues"...   104598    2559
# 28646                                             [none]    37444     660
# 28647  aşk ve mavi 62|"ask ve mavi 62"|"aşk ve mavi 6...   205146    1724
# 28648  samhini 1212|"مسلسل سامحيني"|"2m"|"2mtv"|"tv2m...    17865     348
# 28649  Zap|"actu"|"sport"|"After foot OM"|"After OM"|...     4490      32
# 28650  tuto|"tutoriel"|"fimo"|"creation"|"misscreativ...     3248     318
# 28651                                             [none]     2264     250
# 28652  لقطة جديدة لسقوط الطائرة الجزائرية|"لحظة سقوط ...   472548    2139
# 28653  etrier|"cherbourgeois"|"cours"|"obstacle"|"sau...     4184     423
# 28654  ps5|"playstation 5"|"4k"|"playstation"|"julien...    69450    4887
# 28669       13          277.0  https://i.ytimg.com/vi/zVd5WMemvpA/default.jpg
#
#       comments_disabled ratings_disabled video_error_or_removed  \
# 0                 False            False                  False
# 1                 False            False                  False
# 2                 False            False                  False
# 3                 False            False                  False
# 4                 False            False                  False
# 5                 False            False                  False
# 6                 False            False                  False
# 7                 False            False                  False
# 8                 False            False                  False
# 9                 False            False                  False
# 10                 True             True                  False
# 11                False            False                  False
# 12                False            False                  False
# 13                False            False                  False
# 14                False            False                  False
# 15                False            False                  False
# 16                False            False                  False
# 17                False            False                  False
# 18                False            False                  False
# 19                False            False                  False
# 20                False            False                  False
# 21                False            False                  False
# 22                False            False                  False
# 23                False            False                  False
# 24                False            False                  False
# 25                False            False                  False
# 26                False            False                  False
# 27                False            False                  False
# 28                False            False                  False
# 29                False            False                  False
# ...                 ...              ...                    ...
# 28640             False            False                  False
# 28641             False            False                  False
# 28642             False            False                  False
# 28643              True            False                  False
# 28644             False            False                  False
# 28645             False            False                  False
# 28646             False            False                  False
# 28647             False            False                  False
# 28648             False            False                  False
# 28649             False            False                  False
# 28650             False            False                  False
# 28651             False            False                  False
# 28652             False            False                  False
# 28653             False            False                  False
# 28654             False            False                  False
# 28655             False            False                  False
# 28656             False            False                  False
# 28657             False            False                  False
# 28658             False            False                  False
# 28659             False            False                  False
# 28660             False            False                  False
# 28661             False            False                  False
# 28662             False            False                  False
# 28663             False            False                  False
# 28664             False            False                  False
# 28665             False            False                  False
# 28666             False            False                  False
# 28667             False            False                  False
# 28668             False            False                  False
# 28669             False            False                  False
#
#                                              description
# 0      Dimanche.\n18h30.\nSoyez présents pour la vidé...
# 1      Le jeu de société: https://goo.gl/hhG1Ta\n\nGa...
# 2      Une nouvelle dose de dessins animés français e...
# 3      Nouvel ,épisode de Papy Grenier ! Ce mois-ci o...
# 4      Sauts à plus de 4 mètres de haut dans un tramp...
# 5      Contenu commandité par Netflix France.\nInspir...
# 6      Bonsoir à tous, \nJe tenais beaucoup à retourn...
# 7      Dans Salut Les Terriens, Thierry Ardisson, reç...
# 8      Nouvelle vidéo tous les dimanches matins 10h. ...
# 9             Abonnez-vous et partagez au max la famille
# 10     Jérémy Ferrari - On n'est pas couché 11 novemb...
# 11     Tu sais que ça va pas trop dans ta vie quand u...
# 12     GO 500K !!! JE COMPTE SUR TOI !! : https://goo...
# 13     INCROYABLE ! On est sur le point de remettre l...
# 14     Pour tout savoir sur l'actu Cocovoit !\nTwitte...
# 15     Vous avez lu la BD ? ➡ http://bit.ly/LPMDelc\n...
# 16     👉 Ma page facebook : https://facebook.com/alex...
# 17     A young kid barely avoids getting run over by ...
# 18     LISEZ LA DESCRIPTION JUSQU’À LA FIN OU BIEN NE...
# 19     Si vous pensiez que tous les films pour enfant...
# 20     Ne dites pas ça à siri à 3h du matin, siri fai...
# 21     Ma piscine est sale depuis 30 ans...Quand l'hi...
# 22     One year after the presidential election, John...
# 23     Sophia fascine les journalistes, Jérémy Ferrar...
# 24                       http://www.instagram.com/gmk001
# 25     Abonnez-vous ici : http://bit.ly/2vnYmfc\n12 B...
# 26     Cette semaine, Usul et Cotentin tentent de fai...
# 27     En conférence de presse, Neymar a évoqué sa si...
# 28     Quand la voix ne colle pas au perso, que la tr...
# 29     S'abonner permet d'être coolos : http://bit.ly...
# ...                                                  ...
# 28640  ＬＩＫＥ | ＣＯＭＭＥＮＴ | ＳＨＡＲＥ | ＳＵＢＳＣＲＩＢＥ\n👇 👇 👇 👇 👇 ...
# 28641  شابة جزائرة حرة تقول كلام مؤثر بعد حــادثة تـح...
# 28642                                                NaN
# 28643  FACEBOOK : https://www.facebook.com/Rachid.Elj...
# 28644  Etant invalide, pour m’occuper et me faire pla...
# 28645  Mail professionnel: bestofcultes@gmail.com \nA...
# 28646                                           (PART 4)
# 28647  Kanala Abone Olmak İçin: http://bit.ly/askvema...
# 28648  http://www.2m.ma\nSubscribe: http://goo.gl/JkT...
# 28649                                                NaN
# 28650  ∆∆ REGARDE EN BAS POUR LES INFOS ! ∆∆  \n\n\n\...
# 28651  Hey! J'espère que la vidéo vous a plu !\nDites...
# 28652  لقطة جديدة واضحة تبين لحظة سقوط الطائرة العسكر...
# 28653  DEROULE !\n\nCe cours date du 07 Avril 2018\n\...
# 28654  Les amis, ces dernières semaines ça bougent du...
# 28655  Abonnez-vous à notre chaîne sur YouTube : http...
# 28656  allez, petit épisode sans grande nouveauté. Un...
# 28657  📘Suivre le programme TKL Trader : http://bit.l...
# 28658  En route les amis !! aujourd'hui on remonte to...
# 28659  I للتواصل معنا I\nhttps://www.facebook.com/Red...
# 28660  James asks Victoria Beckham about a recent pho...
# 28661  Voici la nouvelle investigation de  PARANORMAL...
# 28662   لا تنسى الإشتراك في القناة حتى يصلك دائما الجديد
# 28663  JULIEN (LMA) ALERTE ACCOUCHEMENT pour MANON !👶...
# 28664  ♛ ABONNE-TOI ET ACTIVE LA CLOCHE 🔔\n▃▃▃▃▃▃▃▃▃▃...
# 28665  大家都说看完这期真的被点燃了！你觉得呢？哪位演讲家最让你惊艳？快到评论区中留下你的感受吧！\...
# 28666  Bonjour tout le monde, \nAujourd’hui on se ret...
# 28667  Obsèques de Jacques Hige­lin : sa fille Izia ...
# 28668  Mon twitter :   https://twitter.com/lLoup_Soli...
# 28669                                     Rien a ajouté.
#
# [28670 rows x 16 columns]

# %%
FR_csv.describe()
# Out:
#         category_id  comment_count
# count  28670.000000   28668.000000
# mean      20.081758    1622.927968
# std        7.039799   12430.630211
# min        1.000000       0.000000
# 25%       17.000000      45.000000
# 50%       23.000000     201.000000
# 75%       24.000000     761.000000
# max      129.000000  827755.000000

# %%
FR_csv.corr()
# Out:
#                category_id  comment_count
# category_id       1.000000      -0.031472
# comment_count    -0.031472       1.000000

# %%
# video_id                  object
# trending_date             object
# title                     object
# channel_title             object
# category_id                int64
# publish_time              object
# tags                      object
# views                      int64
# likes                      int64
# dislikes                   int64
# comment_count              int64
# thumbnail_link            object
# comments_disabled           bool
# ratings_disabled            bool
# video_error_or_removed      bool
# description               object
FR_csv.dtypes
# Out:
# video_id                   object
# trending_date              object
# title                      object
# channel_title              object
# category_id                 int64
# publish_time               object
# tags                       object
# views                      object
# likes                      object
# dislikes                   object
# comment_count             float64
# thumbnail_link             object
# comments_disabled          object
# ratings_disabled           object
# video_error_or_removed     object
# description                object
# dtype: object

# %%
values = FR_csv.isin(searchfor)
values.to_csv("Values.csv",index=False)

# %%
searchfor = ['Laura Smet veut contester le testament de Johnny Hallyday, qui confie tout son héritage à son épouse Laeticia, comme la fille du rockeur la fait savoir par ses avocats ce lundi 12 février. Sur les réseaux sociaux, les fans du Taulier s\'en sont violemment pris à la veuve de Johnny…\n\nCoup de tonnerre dans la galaxie Hallyday ce lundi 12 février : Laura Smet a annoncé par le biais de ses avocats qu\'elle contestait le testament laissé par Johnny, confiant l\'ensemble de son patrimoine et l\'ensemble de ses droits d\'artiste à sa femme Laeticia, en vertu de la loi californienne. Son demi-frère David Hallyday est codemandeur. Une déclaration qui a choqué les fans français du Taulier, et qui a fait se soule­ver de nombreuses questions, parmi lesquelles : Johnny Hallyday aurait-il pu déshériter ses enfants ? Pour certains, la personne à blâmer n\'est pas tant le Taulier que son épouse…\n\nSur les réseaux sociaux, de nombreux inter­nautes ont pointé la responsabilité de cette crise fami­liale vers Laeticia. « Manipulatrice…, a lâché l\'un d\'entre eux sur le compte instagram de la mère de Jade et Joy.  »Les masques tombent (…) Quelle genre de femme êtes-vous Laeticia ? Vous avez un père vous aussi, réfléchissez au mal que vous avez fait« , a demandé un autre.  »C\'est ECOEURANT pour David et Laura… », a estimé un troisième. Petite profiteuse aucun papa ne ferait ça à ses propres enfants, voleuse, a jugé un dernier.\n\nDes commentaires impitoyables prenant pour cible Laeticia. La veuve du rockeur a néan­moins pu comp­ter sur le soutien d\'autres internautes : « Nous ne savons rien de ce qui se passe. En plus de ça, c\'est une affaire de famille, ça ne nous concerne pas. Toujours juger sans savoir, c\'est décevant… », a rappelé un fan de la mère de famille. Elle s\'en fout Laura de salir la mémoire de son père ? Pas très joli de sa part, je trouve. En plus elle n\'est pas à plaindre question finance, alors elle aurait pu attendre avant d\'étaler sa vie privée« , a commenté un second.  »Laetitia était là quand Johnny était au plus bas et n\'avait plus aucun argent, elle l\'a aidé à remonter. C\'est tout à fait logique que ce soit elle qui hérite de tout », a trouvé un autre. La question de l\'héritage n\'a pas fini de diviser la famille Hallyday comme les fans du clan.']
#FR_csv = FR_csv[~FR_csv.str.contains('|'.join(searchfor))]

# %%
new_FR_df = FR_csv[FR_csv != 'XYZ']
#new_df = df[df.C != 'XYZ']

# %%
#How to find string value in dataframe and drop it 
#df.drop row where string value == 

u déshé\xadri\xadter ses enfants\u202f? Pour certains, la personne à blâmer n'est pas tant le Taulier que son épou\xadse…\\n\\nSur les réseaux sociaux, de nombreux inter\xadnautes ont pointé la respon\xadsa\xadbi\xadlité de cette crise fami\xadliale vers Laeti\xadcia. « Mani\xadpu\xadla\xadtri\xadce…, a lâché l'un d'entre eux sur le compte insta\xadgram de la mère de Jade et Joy.  »Les masques tombent (…) Quelle genre de femme êtes-vous Laeti\xadcia\u202f? Vous avez un père vous aussi, réflé\xadchis\xadsez au mal que vous avez fait« , a demandé un autre.  »C'est ECOEURANT pour David et Laura… », a estimé un troi\xadsième. Petite profi\xadteuse aucun papa ne ferait ça à ses propres enfants, voleuse, a jugé un dernier.\\n\\nDes commen\xadtaires impi\xadtoyables prenant pour cible Laeti\xadcia. La veuve du rockeur a néan\xadmoins pu comp\xadter sur le soutien d'autres inter\xadnautes : « Nous ne savons rien de ce qui se passe. En plus de ça, c'est une affaire de famille, ça ne nous concerne pas. Toujours juger sans savoir, c'est déce\xadvant… », a rappelé un fan de la mère de famille. Elle s'en fout Laura de salir la mémoire de son père\u202f? Pas très joli de sa part, je trouve. En plus elle n'est pas à plaindre ques\xadtion finance, alors elle aurait pu attendre avant d'étaler sa vie privée« , a commenté un second.  »Laeti\xadtia était là quand Johnny était au plus bas et n'avait plus aucun argent, elle l'a aidé à remon\xadter. C'est tout à fait logique que ce soit elle qui hérite de tout », a trouvé un autre. La ques\xadtion de l'héri\xadtage n'a pas fini de divi\xadser la famille Hally\xadday comme les fans du clan."]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
# -> 1328             return self._getitem_axis(key, axis=0)
#    1329
#    1330     def _is_scalar_access(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1740         # a single integer
#    1741         else:
# -> 1742             key = self._convert_scalar_indexer(key, axis)
#    1743
#    1744             if not is_integer(key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_scalar_indexer(self, key, axis)
#     234         ax = self.obj._get_axis(min(axis, self.ndim - 1))
#     235         # a scalar
# --> 236         return ax._convert_scalar_indexer(key, kind=self.name)
#     237
#     238     def _convert_slice_indexer(self, key, axis):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/numeric.py in _convert_scalar_indexer(self, key, kind)
#     140             key = self._maybe_cast_indexer(key)
#     141         return (super(Int64Index, self)
# --> 142                 ._convert_scalar_indexer(key, kind=kind))
#     143
#     144     def _wrap_joined_index(self, joined, other):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in _convert_scalar_indexer(self, key, kind)
#    1306
#    1307         if kind == 'iloc':
# -> 1308             return self._validate_indexer('positional', key, kind)
#    1309
#    1310         if len(self) and not isinstance(self, ABCMultiIndex,):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in _validate_indexer(self, form, key, kind)
#    3386             pass
#    3387         elif kind in ['iloc', 'getitem']:
# -> 3388             self._invalid_indexer(form, key)
#    3389         return key
#    3390
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in _invalid_indexer(self, form, key)
#    1517                         "indexers [{key}] of {kind}".format(
#    1518                             form=form, klass=type(self), key=key,
# -> 1519                             kind=type(key)))
#    1520
#    1521     def get_duplicates(self):
#
# TypeError: cannot do positional indexing on <class 'pandas.core.indexes.range.RangeIndex'> with these indexers [Laura Smet veut contes­ter le testa­ment de Johnny Hally­day, qui confie tout son héri­tage à son épouse Laeti­cia, comme la fille du rockeur l'a fait savoir par ses avocats ce lundi 12 février. Sur les réseaux sociaux, les fans du Taulier s'en sont violem­ment pris à la veuve de John­ny…\n\nCoup de tonnerre dans la galaxie Hally­day ce lundi 12 février : Laura Smet a annoncé par le biais de ses avocats qu'elle contes­tait le testa­ment laissé par Johnny, confiant l'ensemble de son patri­­moine et l'ensemble de ses droits d'artiste à sa femme Laeti­cia, en vertu de la loi cali­­for­­nienne. Son demi-frère David Hally­day est code­man­deur. Une décla­ra­tion qui a choqué les fans français du Taulier, et qui a fait se soule­ver de nombreuses ques­tions, parmi lesquelles : Johnny Hally­day aurait-il pu déshé­ri­ter ses enfants ? Pour certains, la personne à blâmer n'est pas tant le Taulier que son épou­se…\n\nSur les réseaux sociaux, de nombreux inter­nautes ont pointé la respon­sa­bi­lité de cette crise fami­liale vers Laeti­cia. « Mani­pu­la­tri­ce…, a lâché l'un d'entre eux sur le compte insta­gram de la mère de Jade et Joy.  »Les masques tombent (…) Quelle genre de femme êtes-vous Laeti­cia ? Vous avez un père vous aussi, réflé­chis­sez au mal que vous avez fait« , a demandé un autre.  »C'est ECOEURANT pour David et Laura… », a estimé un troi­sième. Petite profi­teuse aucun papa ne ferait ça à ses propres enfants, voleuse, a jugé un dernier.\n\nDes commen­taires impi­toyables prenant pour cible Laeti­cia. La veuve du rockeur a néan­moins pu comp­ter sur le soutien d'autres inter­nautes : « Nous ne savons rien de ce qui se passe. En plus de ça, c'est une affaire de famille, ça ne nous concerne pas. Toujours juger sans savoir, c'est déce­vant… », a rappelé un fan de la mère de famille. Elle s'en fout Laura de salir la mémoire de son père ? Pas très joli de sa part, je trouve. En plus elle n'est pas à plaindre ques­tion finance, alors elle aurait pu attendre avant d'étaler sa vie privée« , a commenté un second.  »Laeti­tia était là quand Johnny était au plus bas et n'avait plus aucun argent, elle l'a aidé à remon­ter. C'est tout à fait logique que ce soit elle qui hérite de tout », a trouvé un autre. La ques­tion de l'héri­tage n'a pas fini de divi­ser la famille Hally­day comme les fans du clan.] of <class 'str'>

# %%
FR_csv[['views','likes','dislikes','comment_count']] = FR_csv[['views','likes','dislikes','comment_count']].astype(float)

# object_to_int_cols = 
# pd.to_numeric(object_to_int_cols) 
# for column in object_to_int_cols:
#     FR_csv[column] = FR_csv[column].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-4aa9a7e3ece3> in <module>()
# ----> 1 FR_csv[['views','likes','dislikes','comment_count']] = FR_csv[['views','likes','dislikes','comment_count']].astype(float)
#       2
#       3 # object_to_int_cols =
#       4 # pd.to_numeric(object_to_int_cols)
#       5 # for column in object_to_int_cols:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
#      93     return _deprecate_kwarg
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    3408         # else, only a single dtype is given
#    3409         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 3410                                      **kwargs)
#    3411         return self._constructor(new_data).__finalize__(self)
#    3412
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in astype(self, dtype, **kwargs)
#    3222
#    3223     def astype(self, dtype, **kwargs):
# -> 3224         return self.apply('astype', dtype=dtype, **kwargs)
#    3225
#    3226     def convert(self, **kwargs):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3089
#    3090             kwargs['mgr'] = self
# -> 3091             applied = getattr(b, f)(**kwargs)
#    3092             result_blocks = _extend_blocks(applied, result_blocks)
#    3093
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in astype(self, dtype, copy, errors, values, **kwargs)
#     469     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     470         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 471                             **kwargs)
#     472
#     473     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in _astype(self, dtype, copy, errors, values, klass, mgr, raise_on_error, **kwargs)
#     519
#     520                 # _astype_nansafe works fine with 1-d only
# --> 521                 values = astype_nansafe(values.ravel(), dtype, copy=True)
#     522                 values = values.reshape(self.shape)
#     523
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy)
#     634
#     635     if copy:
# --> 636         return arr.astype(dtype)
#     637     return arr.view(dtype)
#     638
#
# ValueError: could not convert string to float: "Laura Smet veut contes\xadter le testa\xadment de Johnny Hally\xadday, qui confie tout son héri\xadtage à son épouse Laeti\xadcia, comme la fille du rockeur l'a fait savoir par ses avocats ce lundi 12 février. Sur les réseaux sociaux, les fans du Taulier s'en sont violem\xadment pris à la veuve de John\xadny…\\n\\nCoup de tonnerre dans la galaxie Hally\xadday ce lundi 12 février : Laura Smet a annoncé par le biais de ses avocats qu'elle contes\xadtait le testa\xadment laissé par Johnny, confiant l'ensemble de son patri\xad\xadmoine et l'ensemble de ses droits d'artiste à sa femme Laeti\xadcia, en vertu de la loi cali\xad\xadfor\xad\xadnienne. Son demi-frère David Hally\xadday est code\xadman\xaddeur. Une décla\xadra\xadtion qui a choqué les fans français du Taulier, et qui a fait se soule\xadver de nombreuses ques\xadtions, parmi lesquelles : Johnny Hally\xadday aurait-il pu déshé\xadri\xadter ses enfants\u202f? Pour certains, la personne à blâmer n'est pas tant le Taulier que son épou\xadse…\\n\\nSur les réseaux sociaux, de nombreux inter\xadnautes ont pointé la respon\xadsa\xadbi\xadlité de cette crise fami\xadliale vers Laeti\xadcia. « Mani\xadpu\xadla\xadtri\xadce…, a lâché l'un d'entre eux sur le compte insta\xadgram de la mère de Jade et Joy.  »Les masques tombent (…) Quelle genre de femme êtes-vous Laeti\xadcia\u202f? Vous avez un père vous aussi, réflé\xadchis\xadsez au mal que vous avez fait« , a demandé un autre.  »C'est ECOEURANT pour David et Laura… », a estimé un troi\xadsième. Petite profi\xadteuse aucun papa ne ferait ça à ses propres enfants, voleuse, a jugé un dernier.\\n\\nDes commen\xadtaires impi\xadtoyables prenant pour cible Laeti\xadcia. La veuve du rockeur a néan\xadmoins pu comp\xadter sur le soutien d'autres inter\xadnautes : « Nous ne savons rien de ce qui se passe. En plus de ça, c'est une affaire de famille, ça ne nous concerne pas. Toujours juger sans savoir, c'est déce\xadvant… », a rappelé un fan de la mère de famille. Elle s'en fout Laura de salir la mémoire de son père\u202f? Pas très joli de sa part, je trouve. En plus elle n'est pas à plaindre ques\xadtion finance, alors elle aurait pu attendre avant d'étaler sa vie privée« , a commenté un second.  »Laeti\xadtia était là quand Johnny était au plus bas et n'avait plus aucun argent, elle l'a aidé à remon\xadter. C'est tout à fait logique que ce soit elle qui hérite de tout », a trouvé un autre. La ques\xadtion de l'héri\xadtage n'a pas fini de divi\xadser la famille Hally\xadday comme les fans du clan."

# %%
#Select all columns of type 'object'
object_columns = GB_csv[''].columns
object_columns
