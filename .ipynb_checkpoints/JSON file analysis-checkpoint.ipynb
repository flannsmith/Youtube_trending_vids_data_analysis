# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
sns.set()
from matplotlib import style
from matplotlib.backends.backend_pdf import PdfPages
# %matplotlib inline
# plt.style.use('fivethirtyeight')
plt.style.use(['ggplot'])
# %config IPCompleter.greedy=True
from IPython.display import display
from IPython.display import Image

# %%
def makeDataFrame(jsonData):
    listOfId=[]
    listOfGenre=[]
    for i in jsonData['items']:
        listOfId.append(i['id'])
        listOfGenre.append(i['snippet']['title'])

    genreIds={}
    genreIds['id']=listOfId
    genreIds['Genre']=listOfGenre
    genreDf=pd.DataFrame.from_dict(genreIds)
    return genreDf

# %%
uk_json = pd.read_json("GB_category_id.json", orient='columns', typ='frame', dtype=True, convert_axes=True,)

# %%
genre = makeDataFrame(uk_json)

# %%
genre = genre.reset_index(drop = True)

# %% [markdown]
# #### How to append categories to dataframe based on id

# %%
GB_csv = pd.read_csv("GBvideos.csv")

# %%
#rename category_id to id
GB_youtube_df = GB_csv.rename(columns={'category_id': 'id'})

# %%
GB_youtube_df.head(1)
# Out:
#       video_id trending_date                                          title  \
# 0  Jw1Y-zhQURU      17.14.11  John Lewis Christmas Ad 2017 - #MozTheMonster
#
#   channel_title  id              publish_time  \
# 0    John Lewis  26  2017-11-10T07:38:29.000Z
#
#                                                 tags    views  likes  \
# 0  christmas|"john lewis christmas"|"john lewis"|...  7224515  55681
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0     10247           9479  https://i.ytimg.com/vi/Jw1Y-zhQURU/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
#
#                                          description
# 0  Click here to continue the story and make your...

# %%
GB_youtube_df['id'].dtype
# Out:
# dtype('int64')

# %%
genre['id'].dtype
# Out:
# dtype('O')

# %%
#Need to cast both id's to the same type
genre['id'] = genre['id'].astype(int)

# %%
GB_concat = pd.merge(GB_youtube_df, genre, on=['id'],how='left')

# %%
GB_concat
# Out:
#           video_id trending_date  \
# 0      Jw1Y-zhQURU      17.14.11
# 1      3s1rvMFUweQ      17.14.11
# 2      n1WpP7iowLc      17.14.11
# 3      PUTEiSjKwJU      17.14.11
# 4      rHwDegptbI4      17.14.11
# 5      AumaWl0TNBo      17.14.11
# 6      2Vv-BfVoq4g      17.14.11
# 7      -N5eucPMTTc      17.14.11
# 8      LMCuKltaY3M      17.14.11
# 9      9t9u_yPEidY      17.14.11
# 10     ONQ-fAp5X64      17.14.11
# 11     Dlwf5u2BLAg      17.14.11
# 12     NVCqz2BDfcQ      17.14.11
# 13     MyEqfBkzESU      17.14.11
# 14     b4vTZx_AtHk      17.14.11
# 15     BsfhHKx6ajA      17.14.11
# 16     DIU3xPdhCBI      17.14.11
# 17     pz95u3UVpaM      17.14.11
# 18     jp9hK-jY6yY      17.14.11
# 19     gEHCXl4J9Qo      17.14.11
# 20     OWvCCu2t6Ts      17.14.11
# 21     6p-QzY5bxJ0      17.14.11
# 22     fiusxyygqGk      17.14.11
# 23     QOksZ8VogRw      17.14.11
# 24     lo5ERI5nPbM      17.14.11
# 25     Ja_GMU7-sjs      17.14.11
# 26     _6ViZ13mN9I      17.14.11
# 27     F62QpaPWXDI      17.14.11
# 28     g5c1bk8weaQ      17.14.11
# 29     3qYt_fXdaXY      17.14.11
# ...            ...           ...
# 28391  zVVrfqwA5lQ      18.07.04
# 28392  y0PMqR7IbAQ      18.07.04
# 28393  425M4M3Opkk      18.07.04
# 28394  _AsPY1bQx70      18.07.04
# 28395  ToY6sjSV8h8      18.07.04
# 28396  LJjsm6CVsG8      18.07.04
# 28397  Ek3aeUhHaFY      18.07.04
# 28398  305ryPvU6A8      18.07.04
# 28399  kP3xrSPYi-0      18.07.04
# 28400  LjUXm0Zy_dk      18.07.04
# 28401  m7b8hitvfoE      18.07.04
# 28402  nCWKrEA4FBw      18.07.04
# 28403  aRsOBFhNjVM      18.07.04
# 28404  RQm0nKoODo4      18.07.04
# 28405  aq-phmpUJ_E      18.07.04
# 28406  sFLTqo2emQ8      18.07.04
# 28407  4HU6Z7anycw      18.07.04
# 28408  Wd_idMpg_qQ      18.07.04
# 28409  oSumNo-j-oc      18.07.04
# 28410  pgN-vvVVxMA      18.07.04
# 28411  LPTlvQ1Zet0      18.07.04
# 28412  _I_D_8Z4sJE      18.07.04
# 28413  HgknAaKNaMM      18.07.04
# 28414  XP32nDUMYS8      18.07.04
# 28415  xuAH21DkJow      18.07.04
# 28416  kton-qrKNLc      18.07.04
# 28417  2UByqalCfnk      18.07.04
# 28418  2VggEmXPnGw      18.07.04
# 28419  3v0c6smpHSk      18.07.04
# 28420  8q1NFlE17qs      18.07.04
#
#                                                    title  \
# 0          John Lewis Christmas Ad 2017 - #MozTheMonster
# 1              Taylor Swift: …Ready for It? (Live) - SNL
# 2             Eminem - Walk On Water (Audio) ft. Beyoncé
# 3      Goals from Salford City vs Class of 92 and Fri...
# 4      Dashcam captures truck's near miss with child ...
# 5                           How My Relationship Started!
# 6            Ed Sheeran - Perfect (Official Music Video)
# 7                          CHRISTMAS HAS GONE TO MY HEAD
# 8       Elbow - Golden Slumbers (John Lewis Advert 2017)
# 9      Jennifer Lopez - Amor, Amor, Amor (Official Vi...
# 10           CAN BABIES DO GYMNASTICS?  **World Record**
# 11     TV Reporter Interviews Alleged Bank Robber, Th...
# 12                  Gucci Mane  - Curve (ft. The Weeknd)
# 13                     EXTREME GOLDEN TAN TRANSFORMATION
# 14                      How To Dry a Shirt in 30 Seconds
# 15     Attracting An Alpaca With An Accordion | Nowhe...
# 16     Sam Smith surprises brides at their wedding! (...
# 17     Camila Cabello - Havana (Vertical Video) ft. Y...
# 18         When Someone Has A Crush on You | Lilly Singh
# 19       Taylor Swift - “New Year’s Day” Fan Performance
# 20     SO Much To Tell You | 32 Weeks Pregnant | MOTH...
# 21     The 'Stranger Things' Kids Were Nearly a Motow...
# 22          Marshmello - You & Me (Official Music Video)
# 23     Bastille - World Gone Mad (from Bright: The Al...
# 24       Sharon Needles - Andy Warhol Is Dead [Official]
# 25                     Google Pixelbook: $1000 of Weird!
# 26     GSP and Tyron Woodley Talk About Their Potenti...
# 27                       THE CHEAPEST & BEST EYESHADOWS?
# 28            FIRST TIME IM DOING THIS! TALKS WITH LIZA.
# 29       Sweetie destroys Flav (Sweetie vs. Flavor Flav)
# ...                                                  ...
# 28391            Judas Priest - Spectre (Official Video)
# 28392  Ozuna, Brytiago, Chris Jeday - Bipolar (Video ...
# 28393          Christopher Robin Official Teaser Trailer
# 28394                 Shinedown - DEVIL (Official Video)
# 28395                           Rich The Kid - Plug Walk
# 14     how to dry a shirt in 30 seconds|"how to dry a...    2063667    98804
# 15     rhett and link|"gmm"|"good mythical morning"|"...     728547    12553
# 16     bbc|"music"|"bbc music"|"Sam Smith"|"Wedding"|...     893462    22326
# 17     camila cabello|"camila"|"young thug"|"havana"|...    5476738   286269
# 18     iisuperwomanii|"iisuperwomenii"|"superwoman"|"...    3371669   202676
# 19     American Broadcasting Company|"ABC"|"ABC Netwo...    2237404    72593
# 20     sprinkleofglitter|"sprinkle of glitter"|"Louis...     238843    10028
# 21     James Corden|"The Late Late Show"|"Colbert"|"l...    5541767   263918
# 22     selena gomez wolves|"alone marshmello"|"marshm...    3407008   207262
# 23     music|"official"|"music video"|"Bright"|"Brigh...     626688    25115
# 24     Sharon Needles|"Andy Warhol Is Dead"|"Battle A...      74934     4577
# 25     Google Pixelbook|"Chromebook"|"Pixel"|"$1000"|...    1575525    52829
# 26     TMZ|"TMZ Sports"|"TMZ Sports Channel"|"TMZ 201...      86296      629
# 27     jamie genevieve|"bblogger"|"youtuber"|"makeup"...     110769     5029
# 28     liza|"lizza"|"lizzza"|"lizzzavine"|"lizzzak"|"...    3578502   307435
# 29     flavor of love|"fighting"|"sweetie"|"flavor fl...      28960      399
# ...                                                  ...        ...      ...
# 28391  judas priest|"judas priest spectre"|"judas pri...    1494429    27240
# 28392  Chris|"Jeday"|"Ozuna"|"Brytiago"|"Bipolar"|"Un...   54067360   395019
# 28393  ChristopherRobin DomesticTrailer1 NoGreenband ...    7919156   149679
# 28394  shinedown|"devil"|"official video"|"attention ...    2924302    52045
# 28395  Rich|"The"|"Kid"|"Plug"|"Walk"|"(TDE/ISR"|"PS)...   42844249   476638
# 28396  world star hip hop|"worldstarhiphop"|"worldsta...   53494574   599425
# 28397                                             [none]    4881616   144323
# 28398  anderson paak|"apartment"|"apple"|"apple music...    8486629   114569
# 28399  hot97|"hot97app"|"music"|"video"|"hip hop"|"ra...     931770    27082
# 28400                                             [none]    9419910   255386
# 28401  Flower of the Universe (From Disney's A Wrinkl...    1441725    24390
# 28402                                             [none]    1674907   127388
# 28403  YouTube Poop|"YTP"|"Animation"|"Music"|"Gaming...    1674134    88854
# 28404  katy perry|"juicy j"|"nirvana"|"queen"|"metall...    1230449    82977
# 28405  andrew|"huang"|"andrew huang"|"music"|"musicia...    1291512    30304
# 28406  BOBBY|"SONG"|"JUNE"|"DK"|"CHAN"|"BI"|"iKON"|"바...    3485395   151782
# 28407  LucastheSpider|"Animation"|"3D Animation"|"VFX...    8982414   333141
# 28408  Look alive remix|"drake look alive"|"blocboy j...    6966384   164663
# 28409  sneakerhead|"complex"|"complex originals"|"sne...    1188853    29151
# 28410                                             [none]   72660090  1348854
# 28411  21 savage|"offset"|"metro boomin"|"ric flair d...   69907195   835963
# 28412  Bad Bunny|"Amorfoda"|"Dura"|"Daddy Yankee"|"Oz
# 28393             False                   False
# 28394             False                   False
# 28395             False                   False
# 28396             False                   False
# 28397             False                   False
# 28398             False                   False
# 28399             False                   False
# 28400             False                   False
# 28401             False                   False
# 28402             False                   False
# 28403             False                   False
# 28404             False                   False
# 28405             False                   False
# 28406             False                   False
# 28407             False                   False
# 28408             False                   False
# 28409             False                   False
# 28410             False                   False
# 28411             False                   False
# 28412             False                   False
# 28413             False                   False
# 28414             False                   False
# 28415             False                   False
# 28416             False                   False
# 28417             False                   False
# 28418             False                   False
# 28419             False                   False
# 28420             False                   False
#
#                                              description                 Genre
# 0      Click here to continue the story and make your...         Howto & Style
# 1      Musical guest Taylor Swift performs …Ready for...         Entertainment
# 2      Eminem's new track Walk on Water ft. Beyoncé i...                 Music
# 3      Salford drew 4-4 against the Class of 92 and F...                Sports
# 4      Dashcam captures truck's near miss with child ...       News & Politics
# 5      ► HOW MY RELATIONSHIP STARTED!\n► PB Merch • h...         Entertainment
# 6      🎧: https://ad.gt/yt-perfect\n💰: https://atlant...                 Music
# 7      CHRISTMAS HAS GONE TO MY HEAD\nPrevious Vlog: ...        People & Blogs
# 8      “Golden Slumbers”, originally by The Beatles, ...                 Music
# 9      Jennifer Lopez ft. Wisin - Amor, Amor, Amor (O...                 Music
# 10     ➢ Join my FREE 7 Steps to Success - http://www...                Sports
# 11     More from Inside Edition: https://www.youtube....       News & Politics
# 12     Gucci Mane - Curve feat. The Weeknd\n\n Mr. Da...                 Music
# 13     -\n\n\nWebsite - http://www.johnmaclean.co.uk\...         Howto & Style
# 14     Today I show you how to completely dry a shirt...         Howto & Style
# 15     Trust us, there's nowhere else in the universe...         Entertainment
# 16     You have to watch this! Sam serenades a couple...                 Music
# 17     Havana – Spotify Vertical Video \nVideo Direct...                 Music
# 18     You know that feeling when someone has a crush...                Comedy
# 19     This intimate fan performance of Taylor Swift'...         Entertainment
# 20     A big chat about everything going on in my pre...         Howto & Style
# 21     James and the young stars of Stranger Things -...         Entertainment
# 22     PURCHASE YOU & ME HERE ▶ https://smarturl.it/m...                 Music
# 23     Bastille - World Gone Mad from Bright: The Alb...                 Music
# 24     A Geek Mythology Production \n\nDirector Ben S...                 Music
# 25     Pixelbook is a $1000 2-in-1 laptop/tablet and ...  Science & Technology
# 26     Every Friday on TMZ Sports UFC Welterweight Ch...                Sports
# 27     Subscribe and join the fam! http://www.youtube...        People & Blogs
# 28     Having kids, having anxiety and not having boo...                Comedy
# 29                                             episode 4         Entertainment
# ...                                                  ...                   ...
# 28391  Judas Priest - Spectre (Official Video)\nTaken...                 Music
# 28392  Music video by Chris Jeday, Ozuna, Brytiago pe...                 Music
# 28393  The Hundred Acre Wood is opening up to our wor...      Film & Animation
# 28394  Official video for Shinedown DEVIL\n\nThe new ...                 Music
# 28395  Rich The Kid’s debut album “The World Is Yours...                 Music
# 28396  Watch the official music video for Billy by 6I...                 Music
# 28397  At the old hut site (the new one being tempora...        People & Blogs
# 28398  HomePod. The new sound of home. Directed by Sp...  Science & Technology
# 28399  Royce Da 5'9' and Dj Premier shut it down for ...                 Music
# 28400      .\n[MV] 마마무(MAMAMOO) - 별이 빛나는 밤(Starry night)                 Music
# 28401  Music video by Sade performing Flower of the U...                 Music
# 28402  This video is a look into a day in the studio ...                 Music
# 28403  I'm aware a Steamed Hams/Feel Good Inc. mashup...         Entertainment
# 28404  Watch the Allstar video I did with Seth ► http...                 Music
# 28405  Thanks to LEGO for sponsoring! Watch my episod...                 Music
# 28406  Download on iTunes : http://smarturl.it/iKON_R...                 Music
# 28407  Don't worry...Dexter is a spider friendly pup!...      Film & Animation
# 28408  I'm Kind of A Big Deal Tour: http://www.joyner...                 Music
# 28409  P.J. Tucker goes Sneaker Shopping with Joe La ...         Entertainment
# 28410  enjoy.\n\n? HERE: https://xxxtentacion.lnk.to/...                 Music
# 28411  Without Warning available at\nhttp://smarturl....                 Music
# 28412  Disponible en tu plataforma preferida:\nhttps:...                 Music
# 28413  The Official Music Video for “The Champion” by...                 Music
# 28414  George Ezra - Pretty Shining People (Lyric Vid...                 Music
# 28415  P!NK's new album 'Beautiful Trauma' featuring ...                 Music
# 28416  No Excuses available at Spotify: http://smartu...                 Music
# 28417  Official video for Dancer stream + download ht...                 Music
# 28418  You might not know his face, but you’ve seen h...        People & Blogs
# 28419  February's #Hamildrop collaboration with Weird...      Film & Animation
# 28420  “Pineapple” de Karol G está disponible ya: htt...                 Music
#
# [28421 rows x 17 columns]

# %% [markdown]
# * `  Bar plots `
#
#
# * `Analysis to visualise views/comment_count/likes/dislikes based on genre id`

# %% [markdown]
# ### GB genre analysis

# %%
youtube_genre = GB_concat['Genre']

# %%
sns.barplot(y=youtube_genre, x=GB_concat['views'])

# %%
sns.barplot(x=GB_concat['likes'], y=youtube_genre)

# %%
sns.barplot(y=youtube_genre, x=GB_concat['dislikes'])

# %%
sns.barplot(y=youtube_genre, x=GB_concat['comment_count'])

# %%
#sns.countplot(x=GB_concat['comment_count'], hue=youtube_genre)

# %% [markdown]
# ### US genre analysis

# %%
US_csv = pd.read_csv("USvideos.csv")

# %%
US_json = pd.read_json("US_category_id.json", orient='columns', typ='frame', dtype=True, convert_axes=True,)

# %%
#rename category_id to id
US_csv_df = US_csv.rename(columns={'category_id': 'id'})

# %%
genre = makeDataFrame(US_json)

# %%
#Need to cast both id's to the same type
genre['id'] = genre['id'].astype(int)

# %%
#US_concat = pd.concat([US_csv_df, genre],axis=1)
US_concat = pd.merge(US_csv_df, genre, on=['id'],how='left')

# %%
US_concat.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    id              publish_time  \
# 0  22  2017-11-13T17:13:01.000Z
# 1  24  2017-11-13T07:30:00.000Z
# 2  23  2017-11-12T19:05:24.000Z
# 3  24  2017-11-13T11:00:04.000Z
# 4  24  2017-11-12T18:01:41.000Z
#
#                                                 tags    views   likes  \
# 0                                    SHANtell martin   748374   57527
# 1  last week tonight trump presidency|"last week ...  2418783   97185
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434  146033
# 3  rhett and link|"gmm"|"good mythical morning"|"...   343168   10172
# 4  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...  2095731  132235
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0      2966          15954  https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg
# 1      6146          12703  https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg
# 2      5339           8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3       666           2146  https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg
# 4      1989          17518  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          description           Genre
# 0  SHANTELL'S CHANNEL - https://www.youtube.com/s...  People & Blogs
# 1  One year after the presidential election, John...   Entertainment
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...          Comedy
# 3  Today we find out if Link is a Nickelback amat...   Entertainment
# 4  I know it's been a while since we did this sho...   Entertainment

# %%
US_genre = US_concat['Genre']

# %%
sns.barplot(y=US_genre, x=US_concat['views'])

# %%
sns.barplot(y=US_genre, x=US_concat['likes'])

# %%
sns.barplot(y=US_genre, x=US_concat['dislikes'])

# %%
sns.barplot(y=US_genre, x=US_concat['comment_count'])

# %% [markdown]
# ### Canada genre analysis

# %%
CA_csv = pd.read_csv("CAvideos.csv")

# %%
CA_json = pd.read_json("CA_category_id.json", orient='columns', typ='frame', dtype=True, convert_axes=True,)

# %%
#rename category_id to id
CA_csv_df = CA_csv.rename(columns={'category_id': 'id'})

# %%
genre = makeDataFrame(CA_json)

# %%
#Need to cast both id's to the same type
genre['id'] = genre['id'].astype(int)

# %%
CA_concat = pd.merge(CA_csv_df, genre, on=['id'],how='left')

# %%
CA_concat.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  id  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO  10
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV  23
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso  23
# 3                           I Dare You: GOING BALD!?      nigahiga  24
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran  10
#
#                publish_time  \
# 0  2017-11-10T17:00:03.000Z
# 1  2017-11-13T17:00:00.000Z
# 2  2017-11-12T19:05:24.000Z
# 3  2017-11-12T18:01:41.000Z
# 4  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434   146035
# 3  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828   132239
# 4  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622  1634130
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0     43420         125882  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 1      1688          13030  https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg
# 2      5339           8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3      1989          17518  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
# 4     21082          85067  https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          description          Genre
# 0  Eminem's new track Walk on Water ft. Beyoncé i...          Music
# 1  STill got a lot of packages. Probably will las...         Comedy
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...         Comedy
# 3  I know it's been a while since we did this sho...  Entertainment
# 4  🎧: https://ad.gt/yt-perfect\n💰: https://atlant...          Music

# %%
CA_genre = CA_concat['Genre']

# %%
sns.barplot(y=CA_genre, x=CA_concat['views'])

# %%
sns.barplot(y=CA_genre, x=CA_concat['likes'])

# %%
sns.barplot(y=CA_genre, x=CA_concat['dislikes'])

# %%
sns.barplot(y=CA_genre, x=CA_concat['comment_count'])

# %% [markdown]
# ### Germany genre analysis

# %%
DE_csv = pd.read_csv("DEvideos.csv")

# %%
DE_json = pd.read_json("DE_category_id.json", orient='columns', typ='frame', dtype=True, convert_axes=True,)

# %%
#rename category_id to id
DE_csv_df = DE_csv.rename(columns={'category_id': 'id'})

# %%
genre = makeDataFrame(DE_json)

# %%
genre.dtypes
# Out:
# Genre    object
# id        int64
# dtype: object

# %%
#Need to cast both id's to the same type
genre['id'] = genre['id'].astype(int)

# %%
DE_concat = pd.merge(DE_csv_df, genre, on=['id'],how='left')

# %%
DE_concat.head()
# Out:
#       video_id trending_date  \
# 0  LgVi6y5QIjM      17.14.11
# 1  Bayt7uQith4      17.14.11
# 2  1ZAPwfrtAFY      17.14.11
# 3  AHtypnRk7JE      17.14.11
# 4  ZJ9We4bjcg0      17.14.11
#
#                                                title            channel_title  \
# 0  Sing zu Ende! | Gesangseinlagen vom Feinsten |...                inscope21
# 1  Kinder ferngesteuert im Kiosk! Erwachsene abzo...  LUKE! Die Woche und ich
# 2  The Trump Presidency: Last Week Tonight with J...          LastWeekTonight
# 3                                Das Fermi-Paradoxon        100SekundenPhysik
# 4           18 SONGS mit Kelly MissesVlog (Sing-off)                     rezo
#
#    id              publish_time  \
# 0  24  2017-11-13T17:08:49.000Z
# 1  23  2017-11-12T22:30:01.000Z
# 2  24  2017-11-13T07:30:00.000Z
# 3  27  2017-11-12T15:00:01.000Z
# 4  24  2017-11-12T13:10:36.000Z
#
#                                                 tags    views   likes  \
# 0  inscope21|"sing zu ende"|"gesangseinlagen"|"ge...   252786   35885
# 1  Kinder|"ferngesteuert"|"Kinder ferngesteuert"|...   797196   53576
# 2  last week tonight trump presidency|"last week ...  2418783   97190
# 3  Physik|"Wissenschaft"|"Technik"|"Science-Ficti...   380247   31821
# 4  kelly|"missesvlog"|"kelly song"|"bausa"|"bausa...   822213  100684
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0       230           1539  https://i.ytimg.com/vi/LgVi6y5QIjM/default.jpg
# 1       302           1278  https://i.ytimg.com/vi/Bayt7uQith4/default.jpg
# 2      6146          12703  https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg
# 3       458           1955  https://i.ytimg.com/vi/AHtypnRk7JE/default.jpg
# 4      2467          10244  https://i.ytimg.com/vi/ZJ9We4bjcg0/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          description          Genre
# 0  Heute gibt es mal wieder ein neues Format... w...  Entertainment
# 1  Kinder ferngesteuert! Kinder lassen sich sooo ...         Comedy
# 2  One year after the presidential election, John...  Entertainment
# 3  ►Alle Videos: http://bit.ly/1fa7Tw3\n\n\n✚Snap...      Education
# 4  18 Song Mashup über den (veränderten) Beat von...  Entertainment

# %%
DE_genre = CA_concat['Genre']

# %%
sns.barplot(y=DE_genre, x=DE_concat['views'])

# %%
sns.barplot(y=DE_genre, x=DE_concat['likes'])

# %%
sns.barplot(y=DE_genre, x=DE_concat['dislikes'])

# %%
sns.barplot(y=DE_genre, x=DE_concat['comment_count'])

# %% [markdown]
# ### France genre analysis

# %%
FR_csv = pd.read_csv("FRvideos.csv")

# %%
FR_csv.head(1)
# Out:
#       video_id trending_date                                     title  \
# 0  Ro6eob0LrCY      17.14.11  Malika LePen : Femme de Gauche - Trailer
#
#          channel_title  category_id              publish_time  \
# 0  Le Raptor Dissident           24  2017-11-13T17:32:55.000Z
#
#                                                 tags   views  likes dislikes  \
# 0  Raptor|"Dissident"|"Expliquez"|"moi"|"cette"|"...  212702  29282     1108
#
#    comment_count                                  thumbnail_link  \
# 0         3817.0  https://i.ytimg.com/vi/Ro6eob0LrCY/default.jpg
#
#   comments_disabled ratings_disabled video_error_or_removed  \
# 0             False            False                  False
#
#                                          description
# 0  Dimanche.\n18h30.\nSoyez présents pour la vidé...

# %%
FR_json = pd.read_json("FR_category_id.json", orient='columns', typ='frame', dtype=True, convert_axes=True,)

# %%
#rename category_id to id
FR_csv_df = FR_csv.rename(columns={'category_id': 'id'})

# %%
FR_genre = makeDataFrame(FR_json)

# %%
#Need to cast both id's to the same type
FR_genre['id'] = FR_genre['id'].astype(int)

# %%
FR_genre['id'].dtypes
# Out:
# dtype('int64')

# %%
FR_concat = pd.merge(FR_csv_df, FR_genre, on=['id'],how='left')

# %%
#FR_concat = pd.concat([FR_csv_df, genre],axis=1)

# %%
FR_concat.head()
# Out:
#       video_id trending_date  \
# 0  Ro6eob0LrCY      17.14.11
# 1  Yo84eqYwP98      17.14.11
# 2  ceqntSXE-10      17.14.11
# 3  WuTFI5qftCE      17.14.11
# 4  ee6OFs8TdEg      17.14.11
#
#                                                title        channel_title  id  \
# 0           Malika LePen : Femme de Gauche - Trailer  Le Raptor Dissident  24
# 1  LA PIRE PARTIE ft Le Rire Jaune, Pierre Croce,...              Le Labo  24
# 2  DESSINS ANIMÉS FRANÇAIS VS RUSSES 2 - Daniil...      Daniil le Russe  23
# 3                    PAPY GRENIER - METAL GEAR SOLID    Joueur Du Grenier  20
# 4  QUI SAUTERA LE PLUS HAUT ? (VÉLO SKATE ROLLER ...    Aurelien Fontenoy  17
#
#                publish_time  \
# 0  2017-11-13T17:32:55.000Z
# 1  2017-11-12T15:00:02.000Z
# 2  2017-11-13T17:00:38.000Z
# 3  2017-11-12T17:00:02.000Z
# 4  2017-11-13T16:30:03.000Z
#
#                                                 tags   views  likes dislikes  \
# 0  Raptor|"Dissident"|"Expliquez"|"moi"|"cette"|"...  212702  29282     1108
# 1                                             [none]  432721  14053      576
# 2      cartoon|"pokémon"|"école"|"ours"|"мультфильм"  482153  76203      477
# 3  Papy grenier|"Metal Gear Solid"|"PS1"|"Tirage ...  925222  85016      550
# 4  vélo|"vtt"|"bmx"|"freestyle"|"bike"|"mtb"|"dir...  141695   8091       72
#
#    comment_count                                  thumbnail_link  \
# 0         3817.0  https://i.ytimg.com/vi/Ro6eob0LrCY/default.jpg
# 1         1161.0  https://i.ytimg.com/vi/Yo84eqYwP98/default.jpg
# 2         9580.0  https://i.ytimg.com/vi/ceqntSXE-10/default.jpg
# 3         4303.0  https://i.ytimg.com/vi/WuTFI5qftCE/default.jpg
# 4          481.0  https://i.ytimg.com/vi/ee6OFs8TdEg/default.jpg
#
#   comments_disabled ratings_disabled video_error_or_removed  \
# 0             False            False                  False
# 1             False            False                  False
# 2             False            False                  False
# 3             False            False                  False
# 4             False            False                  False
#
#                                          description          Genre
# 0  Dimanche.\n18h30.\nSoyez présents pour la vidé...  Entertainment
# 1  Le jeu de société: https://goo.gl/hhG1Ta\n\nGa...  Entertainment
# 2  Une nouvelle dose de dessins animés français e...         Comedy
# 3  Nouvel ,épisode de Papy Grenier ! Ce mois-ci o...         Gaming
# 4  Sauts à plus de 4 mètres de haut dans un tramp...         Sports

# %%
FR_concat.dtypes
# Out:
# video_id                   object
# trending_date              object
# title                      object
# channel_title              object
# id                          int64
# publish_time               object
# tags                       object
# views                      object
# likes                      object
# dislikes                   object
# comment_count             float64
# thumbnail_link             object
# comments_disabled          object
# ratings_disabled           object
# video_error_or_removed     object
# description                object
# Genre                      object
# dtype: object

# %%
sns.barplot(y=FR_genre, x=FR_concat['views'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-254-13647f6ccee9> in <module>()
# ----> 1 sns.barplot(y=FR_genre, x=FR_concat['views'])
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    2938                           estimator, ci, n_boot, units,
#    2939                           orient, color, palette, saturation,
# -> 2940                           errcolor, errwidth, capsize, dodge)
#    2941
#    2942     if ax is None:
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1584         """Initialize the plotter."""
#    1585         self.establish_variables(x, y, hue, data, orient,
# -> 1586                                  order, hue_order, units)
#    1587         self.establish_colors(color, palette, saturation)
#    1588         self.estimate_statistic(estimator, ci, n_boot)
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     152
#     153             # Figure out the plotting orientation
# --> 154             orient = self.infer_orient(x, y, orient)
#     155
#     156             # Option 2a:
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in infer_orient(self, x, y, orient)
#     347         elif is_not_numeric(y):
#     348             if is_not_numeric(x):
# --> 349                 raise ValueError(no_numeric)
#     350             else:
#     351                 return "h"
#
# ValueError: Neither the `x` nor `y` variable appears to be numeric.
