# %%
import pandas as pd

# %%
def makeDataFrame(jsonData):
    listOfId=[]
    listOfGenre=[]
    for i in jsonData['items']:
        listOfId.append(i['id'])
        listOfGenre.append(i['snippet']['title'])

    genreIds={}
    genreIds['id']=listOfId
    genreIds['Genre']=listOfGenre
    genreDf=pd.DataFrame.from_dict(genreIds)
    return genreDf

# %%
uk_json = pd.read_json("GB_category_id.json", orient='columns', typ='frame', dtype=True, convert_axes=True,)

# %%
makeDataFrame(uk_json)
# Out:
#                    Genre  id
# 0       Film & Animation   1
# 1       Autos & Vehicles   2
# 2                  Music  10
# 3         Pets & Animals  15
# 4                 Sports  17
# 5           Short Movies  18
# 6        Travel & Events  19
# 7                 Gaming  20
# 8          Videoblogging  21
# 9         People & Blogs  22
# 10                Comedy  23
# 11         Entertainment  24
# 12       News & Politics  25
# 13         Howto & Style  26
# 14             Education  27
# 15  Science & Technology  28
# 16                Movies  30
# 17       Anime/Animation  31
# 18      Action/Adventure  32
# 19              Classics  33
# 20                Comedy  34
# 21           Documentary  35
# 22                 Drama  36
# 23                Family  37
# 24               Foreign  38
# 25                Horror  39
# 26        Sci-Fi/Fantasy  40
# 27              Thriller  41
# 28                Shorts  42
# 29                 Shows  43
# 30              Trailers  44

# %% [markdown]
# `Bar plots `
#
# `Analysis to count comment_count/likes/dislikes vs genre id`
